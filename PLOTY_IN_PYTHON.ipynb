# %% [markdown]
# <a href="https://colab.research.google.com/github/Ujjawal19Shahi/AI-in-Data-Science/blob/main/PLOTY_IN_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly as plt
