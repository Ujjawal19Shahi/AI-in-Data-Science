# %% [markdown]
# <a href="https://colab.research.google.com/github/Ujjawal19Shahi/AI-in-Data-Science/blob/main/SEABORN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DATA VISUALISATION WITH SEABORN**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3a6daa61-e7ee-4ed1-9553-5af5b221d15a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a6daa61-e7ee-4ed1-9553-5af5b221d15a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('penguins.csv')
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
from numpy import size
sns.lineplot(x='bill_length_mm',y='bill_depth_mm',data=df,hue="sex",palette="BuPu",markers=["o","s"],style="sex",dashes=True,legend="full")
plt.show()
sns.set_theme(style="ticks", palette="pastel")
sns.displot(data=df, x='bill_depth_mm', kde=True, bins=[14,20])

# %%
sns.scatterplot(data=df, x='bill_length_mm', y='bill_depth_mm', hue='species')
plt.figure(figsize=(10,10))
sns.set_theme(style='darkgrid',context="notebook")
plt.show()

# %%
sns.lineplot(x='bill_length_mm', y='bill_depth_mm', data=df, hue='species')
plt.figure(figsize=(10,10))
sns.set_style('darkgrid')
plt.show()

# %%
sns.histplot(data=df, x='bill_length_mm', hue='species')
plt.figure(figsize=(10,10))
sns.set_style('darkgrid')
plt.show()

# %%
sns.boxplot(data=df, x='species', y='bill_length_mm')
plt.figure(figsize=(10,10))
plt.show()

# %%
sns.violinplot(data=df, x='species', y='bill_length_mm')
plt.figure(figsize=(10,10))
plt.show()

# %%
sns.barplot(data=df, x='species', y='bill_length_mm')
plt.figure(figsize=(10,10))
plt.show()
